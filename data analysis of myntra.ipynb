# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn import linear_model

# %% [markdown]
# # Loading The Dataset

# %%
df = pd.read_csv('Fashion Dataset.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %%
df
# Out:
#        u_id        p_id                                               name  \
# 0         0  17048614.0  Khushal K Women Black Ethnic Motifs Printed Ku...
# 1         1  16524740.0  InWeave Women Orange Solid Kurta with Palazzos...
# 2         2  16331376.0  Anubhutee Women Navy Blue Ethnic Motifs Embroi...
# 3         3  14709966.0  Nayo Women Red Floral Printed Kurta With Trous...
# 4         4  11056154.0   AHIKA Women Black & Green Printed Straight Kurta
# ...     ...         ...                                                ...
# 14325   985  15415116.0  Flying Machine Women Blue Solid Mock-Collar Fr...
# 14326   986  16470114.0       Juelle Women Green Printed Hooded Sweatshirt
# 14327   987  16382150.0                    Vero Moda Women Pink Sweatshirt
# 14328   988  16379664.0                    Vero Moda Women Blue Sweatshirt
# 14329   989  16379656.0  Vero Moda Women Grey & Green Colourblocked Swe...
#
#         price     colour           brand  \
# ...

# %%
df.head(10)
# Out:
#    u_id        p_id                                               name  \
# 0     0  17048614.0  Khushal K Women Black Ethnic Motifs Printed Ku...
# 1     1  16524740.0  InWeave Women Orange Solid Kurta with Palazzos...
# 2     2  16331376.0  Anubhutee Women Navy Blue Ethnic Motifs Embroi...
# 3     3  14709966.0  Nayo Women Red Floral Printed Kurta With Trous...
# 4     4  11056154.0   AHIKA Women Black & Green Printed Straight Kurta
# 5     5  18704418.0  Soch Women Red Thread Work Georgette Anarkali ...
# 6     6  14046594.0  Libas Women Navy Blue Pure Cotton Floral Print...
# 7     7  14951330.0  Ahalyaa Women Beige Floral Printed Regular Got...
# 8     8  13791594.0  Anouk Women Yellow & White Printed Kurta with ...
# 9     9  17048604.0  Khushal K Women Green & Pink Printed Pure Cott...
#
#     price     colour      brand  \
# 0  5099.0      Black  Khushal K
# 1  5899.0     Orange    InWeave
# 2  4899.0  Navy Blue  Anubhutee
# 3  3699.0        Red       Nayo
# ...

# %%
df.tail(10)
# Out:
#        u_id        p_id                                               name  \
# 14320   980  16804476.0  JoE Hazel Women Red Asymmetric Tasseled Detail...
# 14321   981  16804460.0       JoE Hazel Women Red & Black Fair Isle Poncho
# 14322   982  15007890.0  Hubberholme Women Navy Blue Solid Cropped Swea...
# 14323   983  16225448.0      The Vanca Women Olive Green Hooded Sweatshirt
# 14324   984  16571966.0  Latin Quarters Women Beige Checked Acrylic Pon...
# 14325   985  15415116.0  Flying Machine Women Blue Solid Mock-Collar Fr...
# 14326   986  16470114.0       Juelle Women Green Printed Hooded Sweatshirt
# 14327   987  16382150.0                    Vero Moda Women Pink Sweatshirt
# 14328   988  16379664.0                    Vero Moda Women Blue Sweatshirt
# 14329   989  16379656.0  Vero Moda Women Grey & Green Colourblocked Swe...
#
#         price     colour           brand  \
# 14320  1799.0        Red       JoE Hazel
# 14321  1799.0        Red       JoE Hazel
# ...

# %%
df.shape
# Out:
# (14330, 11)

# %%
df.columns
# Out:
# Index(['u_id', 'p_id', 'name', 'price', 'colour', 'brand', 'img',
#        'ratingCount', 'avg_rating', 'description', 'p_attributes'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=14330, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14330 entries, 0 to 14329
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   u_id          14330 non-null  int64
#  1   p_id          14312 non-null  float64
#  2   name          14312 non-null  object
#  3   price         14312 non-null  float64
#  4   colour        14309 non-null  object
#  5   brand         14312 non-null  object
#  6   img           14312 non-null  object
#  7   ratingCount   6581 non-null   float64
#  8   avg_rating    6581 non-null   float64
#  9   description   14312 non-null  object
#  10  p_attributes  14312 non-null  object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#                u_id          p_id         price   ratingCount   avg_rating
# count  14330.000000  1.431200e+04  14312.000000   6581.000000  6581.000000
# mean     456.998255  1.569151e+07   2964.229248    184.479410     4.101226
# std      279.547902  3.153526e+06   2563.850645    782.501137     0.475633
# min        0.000000  7.016600e+04    169.000000      1.000000     1.000000
# 25%      215.000000  1.413619e+07   1599.000000      9.000000     3.888889
# 50%      442.500000  1.638232e+07   2200.000000     23.000000     4.180822
# 75%      687.000000  1.808456e+07   3495.000000     80.000000     4.392857
# max      989.000000  1.941576e+07  47999.000000  21274.000000     5.000000

# %%
df.describe(include = 'object')
# Out:
#                                        name colour     brand  \
# count                                 14312  14309     14312
# unique                                13882     49      1022
# top     SCORPIOUS Women Pack of Shrug & Top  Black  Roadster
# freq                                     10   1917       346
#
#                                                       img  \
# count                                               14312
# unique                                              14223
# top     http://assets.myntassets.com/assets/images/136...
# freq                                                    2
#
#                                               description  \
# count                                               14312
# unique                                              14235
# top     White light wash 5-pocket high-rise jeans, cle...
# freq                                                    3
#
#                                              p_attributes
# ...

# %%
for col in df. describe(include = 'object').columns:
    print(col)
    print(df[col].unique())
# Out:
# name
# ['Khushal K Women Black Ethnic Motifs Printed Kurta with Palazzos & With Dupatta'
#  'InWeave Women Orange Solid Kurta with Palazzos & Floral Print Dupatta'
#  'Anubhutee Women Navy Blue Ethnic Motifs Embroidered Thread Work Kurta with Trousers & With Dupatta'
#  ... 'Vero Moda Women Pink Sweatshirt' 'Vero Moda Women Blue Sweatshirt'
#  'Vero Moda Women Grey & Green Colourblocked Sweatshirt']
# colour
# ['Black' 'Orange' 'Navy Blue' 'Red' 'Beige' 'Yellow' 'Green' 'Pink'
#  'Mustard' 'Teal' 'Peach' 'Maroon' 'Blue' 'Sea Green' 'Lime Green'
#  'Burgundy' 'Fluorescent Green' 'Lavender' 'Magenta' 'Purple' 'White'
#  'Off White' 'Charcoal' 'Cream' 'Copper' 'Multi' 'Mauve' 'Grey' 'Brown'
#  'Turquoise Blue' 'Rust' 'Violet' 'Assorted' nan 'Fuchsia' 'Olive' 'Coral'
#  'Grey Melange' 'Rose' 'Gold' 'Khaki' 'Tan' 'Coffee Brown' 'Silver' 'Nude'
#  'Camel Brown' 'Taupe' 'Bronze' 'Champagne' 'Rose Gold']
# brand
# ['Khushal K' 'InWeave' 'Anubhutee' ... 'ONEWAY' 'Karen Scott'
# ...

# %%
df.isnull().sum()
# Out:
# u_id               0
# p_id              18
# name              18
# price             18
# colour            21
# brand             18
# img               18
# ratingCount     7749
# avg_rating      7749
# description       18
# p_attributes      18
# dtype: int64

# %%
df.dropna (inplace = True)

# %%
df.isnull().sum()
# Out:
# u_id            0
# p_id            0
# name            0
# price           0
# colour          0
# brand           0
# img             0
# ratingCount     0
# avg_rating      0
# description     0
# p_attributes    0
# dtype: int64

# %%
df.describe()
# Out:
#               u_id          p_id         price   ratingCount   avg_rating
# count  6581.000000  6.581000e+03   6581.000000   6581.000000  6581.000000
# mean    414.312263  1.415573e+07   2485.599757    184.479410     4.101226
# std     280.994433  3.162796e+06   1847.523179    782.501137     0.475633
# min       0.000000  8.001500e+04    199.000000      1.000000     1.000000
# 25%     162.000000  1.277345e+07   1495.000000      9.000000     3.888889
# 50%     385.000000  1.465063e+07   1999.000000     23.000000     4.180822
# 75%     644.000000  1.635190e+07   2899.000000     80.000000     4.392857
# max     989.000000  1.926687e+07  33350.000000  21274.000000     5.000000

# %%
cat_data = df.select_dtypes(include = 'object')

# %%
num_data = df.select_dtypes(exclude = 'object')

# %%
for i in num_data.columns:
    sns.boxplot(x=df[i])
    plt.show()

# %%
df['ratingCount'].describe()
# Out:
# count     6581.000000
# mean       184.479410
# std        782.501137
# min          1.000000
# 25%          9.000000
# 50%         23.000000
# 75%         80.000000
# max      21274.000000
# Name: ratingCount, dtype: float64

# %%
q1 = 9
q2 = 23
q3 = 80

iqr = q3 - q1
upper_lim = q3+1.5+iqr
lower_lim = q3-1.5+iqr

# %%
lower_lim , upper_lim
# Out:
# (149.5, 152.5)

# %%
df = df[df['ratingCount']<10000]

# %%
df.describe()
# Out:
#               u_id          p_id         price  ratingCount   avg_rating
# count  6572.000000  6.572000e+03   6572.000000  6572.000000  6572.000000
# mean    414.862751  1.416032e+07   2486.806299   164.616251     4.101155
# std     280.791537  3.161427e+06   1848.410598   555.270873     0.475886
# min       0.000000  8.001500e+04    199.000000     1.000000     1.000000
# 25%     163.000000  1.277537e+07   1495.000000     9.000000     3.888889
# 50%     386.000000  1.466414e+07   1999.000000    23.000000     4.181114
# 75%     644.000000  1.636050e+07   2899.000000    79.000000     4.392857
# max     989.000000  1.926687e+07  33350.000000  9229.000000     5.000000

# %% [markdown]
# # Data Analysis and Visualizations

# %%
df
# Out:
#        u_id        p_id                                               name  \
# 0         0  17048614.0  Khushal K Women Black Ethnic Motifs Printed Ku...
# 1         1  16524740.0  InWeave Women Orange Solid Kurta with Palazzos...
# 2         2  16331376.0  Anubhutee Women Navy Blue Ethnic Motifs Embroi...
# 3         3  14709966.0  Nayo Women Red Floral Printed Kurta With Trous...
# 6         6  14046594.0  Libas Women Navy Blue Pure Cotton Floral Print...
# ...     ...         ...                                                ...
# 14298   958  14927330.0            H&M Women Beige Solid Sleeveless Hoodie
# 14305   965   7275903.0           Belle Fille Women Black Solid Sweatshirt
# 14313   973  16044104.0           SASSAFRAS Women Black Printed Sweatshirt
# 14323   983  16225448.0      The Vanca Women Olive Green Hooded Sweatshirt
# 14325   985  15415116.0  Flying Machine Women Blue Solid Mock-Collar Fr...
#
#         price     colour           brand  \
# ...

# %%
df['ratingCount'].mean()
# Out:
# 164.6162507608034

# %%
for i in df['ratingCount']:
    print(i)
    break
# Out:
# 4522.0

# %% [markdown]
# # most Expensive Product

# %%
df['price'].max()
# Out:
# 33350.0

# %% [markdown]
# **row details of max pro**

# %%
df[df['price'] == 33350.0]
# Out:
#        u_id        p_id                                               name  \
# 10213   363  15721148.0  Readiprint Fashions Magenta Embroidered Semi-S...
#
#          price   colour                brand  \
# 10213  33350.0  Magenta  Readiprint Fashions
#
#                                                      img  ratingCount  \
# 10213  http://assets.myntassets.com/assets/images/157...          4.0
#
#        avg_rating                                        description  \
# 10213        3.25  Magenta embroidered lehenga choli with dupatta...
#
#                                             p_attributes
# 10213  {'Blouse Closure': 'NA', 'Blouse Fabric': 'Raw...

# %%
df['price'].min()
# Out:
# 199.0

# %%
df[df['price'] == 199.0]
# Out:
#       u_id        p_id                   name  price colour brand  \
# 1210   220  14432282.0  max White Regular Top  199.0  White   max
# 1508   518  14432274.0  max Cream Regular Top  199.0  Cream   max
#
#                                                     img  ratingCount  \
# 1210  http://assets.myntassets.com/assets/images/pro...        308.0
# 1508  http://assets.myntassets.com/assets/images/pro...        262.0
#
#       avg_rating                                        description  \
# 1210    4.464286  <ul> <li> White regular top </li> <li> Solid <...
# 1508    4.576336  <ul><li>Cream regular top</li><li>Solid</li><l...
#
#                                            p_attributes
# 1210  {'Body Shape ID': '443,333,324,424', 'Body or ...
# 1508  {'Body Shape ID': '443,333,324,424', 'Body or ...

# %% [markdown]
# # Red Colour dress

# %%
df[df['colour'] == 'Red']
# Out:
#        u_id        p_id                                               name  \
# 3         3  14709966.0  Nayo Women Red Floral Printed Kurta With Trous...
# 26       26  12766966.0  Ishin Women Red & Orange Bandhani Print Anarka...
# 38       38   7763575.0          Anouk Women Red Floral Print A-Line Kurta
# 44       44  15646472.0  Varanga Women Red Bandhani Printed Gotta Patti...
# 73       73  11434632.0  Inddus Women Red Embroidered Kurta with Trouse...
# ...     ...         ...                                                ...
# 13853   513  14080610.0  DressBerry Women Red & Blue Colourblocked Hood...
# 13949   609  12498512.0    Cayman Women Red Solid Pullover Acrylic Sweater
# 13964   624  12684646.0           Alcis Women Red Solid Outdoor Sweatshirt
# 14098   758   2223198.0      W Women Red Solid Front-Open Longline Sweater
# 14193   853  15845708.0  URBANIC Women Plus Size Red & Black Colourbloc...
#
#         price colour       brand  \
# ...

# %%
df_pr = df[df['price'] <3000]
df_pr = df_pr[df_pr['price'] >2000]

# %%
df_pr = df_pr[df_pr['brand'] == 'DressBerry']

# %%
df_pr
# Out:
#        u_id        p_id                                               name  \
# 2135    155  16860084.0     DressBerry Women Black Solid Stretchable Jeans
# 2800    820  15056142.0  DressBerry Women Black Skinny Fit High-Rise St...
# 5948      8  13179468.0  DressBerry Women Magenta & White Floral Printe...
# 5962     22  16187592.0  DressBerry Women Orange Seersucker Capri Jumpsuit
# 5977     37  14218502.0       DressBerry Olive Green Solid Belted Jumpsuit
# 5988     48  14217898.0                DressBerry Women Red Basic Jumpsuit
# 6048    108  14217838.0  DressBerry Charcoal Solid Sustainable & Recycl...
# 6340    400  14218474.0  DressBerry Women Red Geometric Print Basic Jum...
# 6345    405  16187594.0  DressBerry Women Rust Red Solid Sustainable Ba...
# 6453    513  16187598.0  DressBerry Women Olive Green Seersucker Capri ...
# 6459    519  16187596.0  DressBerry Black Solid Sustainable Basic Jumpsuit
# ...

# %%
df.sort_values(by = 'price',ascending = False)
# Out:
#        u_id        p_id                                               name  \
# 10213   363  15721148.0  Readiprint Fashions Magenta Embroidered Semi-S...
# 10191   341  11411284.0  Shaily Off-White & Pink Embroidered Semi-Stitc...
# 10423   573  13980416.0  V SALES Red & Gold-Toned Embroidered Semi-Stit...
# 10072   222  17932228.0  WHITE FIRE Purple & Silver-Toned Semi-Stitched...
# 9951    101  17932234.0  WHITE FIRE Green & Silver-Toned Embellished Se...
# ...     ...         ...                                                ...
# 11085   245  15266700.0                      max Beige Pure Cotton Dupatta
# 11088   248  15011850.0                             Soch Navy Blue Dupatta
# 1358    368  14846678.0      Jockey Women Black Pure Cotton Solid Tank Top
# 1210    220  14432282.0                              max White Regular Top
# 1508    518  14432274.0                              max Cream Regular Top
#
#          price     colour                brand  \
# ...

# %%
df['brand'].nunique()
# Out:
# 615

# %%
df['brand'].unique()
# Out:
# array(['Khushal K', 'InWeave', 'Anubhutee', 'Nayo', 'Libas', 'Ahalyaa',
#        'Anouk', 'Varanga', 'AHIKA', 'Vishudh', 'JAIPURI BUNAAI', 'KALINI',
#        'Indo Era', 'Ishin', 'Virah Fashion', 'Kvsfab',
#        'AASI - HOUSE OF NAYO', 'Indi INSIDE', 'DIVYANK', 'Sangria',
#        'Shae by SASSAFRAS', 'Myshka', 'heemara', 'HERE&NOW', 'Rustorange',
#        'Stylum', 'Inddus', 'anayna', 'Biba', 'Yufta', 'Prakhya',
#        'Meeranshi', 'mokshi', 'Divena', 'Rajnandini', 'Jaipur Kurti',
#        'Yuris', 'Vbuyz', 'Bhama Couture', 'House of Pataudi', 'SheWill',
#        'PRENEA', 'W', 'FASHION DEPTH', 'Ode by House of Pataudi',
#        'Popnetic', 'Ojjasvi', 'ANAISA', 'EXTRA LOVE BY LIBAS', 'ZIYAA',
#        'GERUA', 'AURELIA', 'POONAM DESIGNER', 'Janasya', 'all about you',
#        'Pistaa', 'ADA', 'GLAM ROOTS', 'max', 'FASHOR', 'KETCH', 'IkDaiya',
#        'Aayna', 'Tikhi Imli', 'PIROH', 'KAAJH', 'trueBrowns',
#        'Moda Rapido', 'ZOLA', 'SWAGG INDIA', 'GULMOHAR JAIPUR',
# ...

# %%
for brand in df['brand'].unique():
    c = 0
    for i in df['brand']:
        if(i == brand):
           c += 1
    print(brand,c)
# Out:
# Khushal K 7
# InWeave 25
# Anubhutee 24
# Nayo 32
# Libas 50
# Ahalyaa 19
# Anouk 168
# Varanga 60
# AHIKA 23
# Vishudh 122
# JAIPURI BUNAAI 2
# KALINI 82
# Indo Era 51
# Ishin 18
# Virah Fashion 1
# Kvsfab 12
# AASI - HOUSE OF NAYO 5
# Indi INSIDE 1
# DIVYANK 4
# Sangria 104
# Shae by SASSAFRAS 57
# Myshka 18
# heemara 2
# HERE&NOW 84
# Rustorange 2
# Stylum 7
# Inddus 61
# anayna 25
# Biba 49
# Yufta 8
# Prakhya 3
# Meeranshi 5
# mokshi 6
# Divena 7
# Rajnandini 15
# Jaipur Kurti 32
# Yuris 11
# Vbuyz 5
# Bhama Couture 45
# House of Pataudi 40
# SheWill 4
# PRENEA 1
# W 54
# FASHION DEPTH 3
# Ode by House of Pataudi 6
# Popnetic 10
# Ojjasvi 3
# ANAISA 1
# EXTRA LOVE BY LIBAS 6
# ZIYAA 7
# GERUA 4
# AURELIA 23
# POONAM DESIGNER 2
# Janasya 23
# all about you 56
# Pistaa 1
# ADA 15
# GLAM ROOTS 1
# max 33
# FASHOR 7
# KETCH 3
# IkDaiya 2
# Aayna 4
# Tikhi Imli 12
# PIROH 1
# KAAJH 1
# trueBrowns 1
# Moda Rapido 16
# ZOLA 19
# SWAGG INDIA 9
# GULMOHAR JAIPUR 3
# ...

# %%
df.head(100).groupby('brand').size().sort_values(ascending = False)
# Out:
# brand
# Anouk                   14
# Indo Era                10
# Libas                    9
# Varanga                  7
# Nayo                     5
# KALINI                   5
# Biba                     4
# Vishudh                  3
# AHIKA                    3
# Khushal K                3
# Sangria                  3
# Anubhutee                3
# Ahalyaa                  3
# Inddus                   2
# HERE&NOW                 2
# Myshka                   2
# Shae by SASSAFRAS        2
# Yufta                    1
# Rustorange               1
# Virah Fashion            1
# Yuris                    1
# anayna                   1
# heemara                  1
# Stylum                   1
# AASI - HOUSE OF NAYO     1
# Kvsfab                   1
# Rajnandini               1
# Prakhya                  1
# Meeranshi                1
# Jaipur Kurti             1
# JAIPURI BUNAAI           1
# Ishin                    1
# Indi INSIDE              1
# InWeave                  1
# ...

# %%
df.groupby('brand')['price'].mean()
# Out:
# brand
# 20Dresses          2145.000000
# 513                2099.000000
# 98 Degree North    1979.000000
# 9teenAGAIN         2249.000000
# A.T.U.N.           1232.333333
#                       ...
# toothless           999.000000
# trueBrowns         2999.000000
# urSense            1899.000000
# wild U             2990.000000
# zebu               1499.000000
# Name: price, Length: 615, dtype: float64

# %%
df.groupby('brand')['avg_rating'].mean().sort_values(ascending = False)
# Out:
# brand
# MONJOLIKA FASHION     5.000000
# Charukriti            5.000000
# Hopscotch             5.000000
# SHINGORA              5.000000
# Kook N Keech Emoji    5.000000
#                         ...
# Baby Lakshmi          2.000000
# PINKSKY               2.000000
# ZALORA WORK           2.000000
# Park Avenue           1.666667
# Femme Luxe            1.000000
# Name: avg_rating, Length: 615, dtype: float64

# %%
df.head(3)
# Out:
#    u_id        p_id                                               name  \
# 0     0  17048614.0  Khushal K Women Black Ethnic Motifs Printed Ku...
# 1     1  16524740.0  InWeave Women Orange Solid Kurta with Palazzos...
# 2     2  16331376.0  Anubhutee Women Navy Blue Ethnic Motifs Embroi...
#
#     price     colour      brand  \
# 0  5099.0      Black  Khushal K
# 1  5899.0     Orange    InWeave
# 2  4899.0  Navy Blue  Anubhutee
#
#                                                  img  ratingCount  avg_rating  \
# 0  http://assets.myntassets.com/assets/images/170...       4522.0    4.418399
# 1  http://assets.myntassets.com/assets/images/165...       1081.0    4.119334
# 2  http://assets.myntassets.com/assets/images/163...       1752.0    4.161530
#
#                                          description  \
# 0  Black printed Kurta with Palazzos with dupatta...
# 1  Orange solid Kurta with Palazzos with dupatta<...
# 2  Navy blue embroidered Kurta with Trousers with...
#
# ...

# %%
sns.heatmap(df.corr().round(2))
# Out:
# C:\Users\wwwma\AppData\Local\Temp\ipykernel_15340\159919244.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr().round(2))
# <Axes: >

# %%
plt.figure(figsize =(6,4))
plt.title('Ratings')
plt.bar(['ratingCount','avg_rating'], edgecolor = 'k', width =0.5,height = 3)
plt.show()

# %%
a = sns.catplot(data = df, y = 'ratingCount', x = 'brand', kind = 'bar')
a.fig.set_figwidth(20)
a.fig.set_figheight(10)

# %%
a = sns.catplot(data = df, y = 'ratingCount', x = 'colour', kind = 'bar')
a.fig.set_figwidth(40)
a.fig.set_figheight(20)

# %%
a = sns.catplot(data = df, y = 'ratingCount', x = 'price', kind = 'bar')
a.fig.set_figwidth(20)
a.fig.set_figheight(10)

# %%
plt.figure(figsize = (20,30))
plt.scatter('x','y')
plt.xlabel('price')
plt.ylabel('ratingCount')
plt.show()

# %%
# %matplotlib inline
plt.scatter(df.price, df.ratingCount,color = 'red' , marker ='*')
plt.xlabel('price')
plt.ylabel('ratingCount')
# Out:
# Text(0, 0.5, 'ratingCount')
